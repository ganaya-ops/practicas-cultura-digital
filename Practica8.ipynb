# %%
var = 2
while(var != "5"):
  print("Elige una opcion")
  var=input("")
  if(var=="1"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1+var2)
  elif(var=="2"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1*var2)
  elif(var=="3"):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1-var2)
  elif(var==4):
    var1=int(input("dame un numero"))
    var2=int(input("dame otro numero"))
    print(var1/var2)
# Out:
# Elige una opcion
# 5
